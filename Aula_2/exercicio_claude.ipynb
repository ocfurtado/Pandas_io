# %%
import pandas as pd

# %%
dados_brutos = pd.read_excel('beneficios_funcionarios.xlsx',
                             sheet_name='dados_brutos',
                             skiprows=3,
                             dtype={'matricula': str},
                             usecols='A:E')

# %%
dados_brutos
# Out:
#   matricula               nome_completo departamento  tipo_beneficio  \
# 0     10045  Maria Conceição dos Santos   Financeiro              VR
# 1     00123       Antônio Lopes Pereira           RH              VA
# 2     11501          Jaquelina da Silva           TI  Plano de Saúde
# 3     23256            José de Oliveira      Compras              VR
# 4     89856           Amando dos Santos   Licitações              VR
#
#    valor_mensal
# 0        850.00
# 1       1125.00
# 2       2500.00
# 3        185.29
# 4       1113.25

# %%
tabela_desconto = pd.read_excel('beneficios_funcionarios.xlsx',
                                sheet_name='tabela_desconto')

# %%
tabela_desconto
# Out:
#    tipo_beneficio  percentual_desconto
# 0              VR                 0.05
# 1              VA                 0.03
# 2  Plano de Saúde                 0.12
# 3              VA                 1.12
# 4  Plano de Saúde                 2.12

# %%
dados_consolidados = dados_brutos.join(tabela_desconto, rsuffix='_desconto')

# %%
dados_consolidados
# Out:
#   matricula               nome_completo departamento  tipo_beneficio  \
# 0     10045  Maria Conceição dos Santos   Financeiro              VR
# 1     00123       Antônio Lopes Pereira           RH              VA
# 2     11501          Jaquelina da Silva           TI  Plano de Saúde
# 3     23256            José de Oliveira      Compras              VR
# 4     89856           Amando dos Santos   Licitações              VR
#
#    valor_mensal tipo_beneficio_desconto  percentual_desconto
# 0        850.00                      VR                 0.05
# 1       1125.00                      VA                 0.03
# 2       2500.00          Plano de Saúde                 0.12
# 3        185.29                      VA                 1.12
# 4       1113.25          Plano de Saúde                 2.12

# %%
dados_consolidados['valor_desconto'] = (
    dados_consolidados['valor_mensal'] * dados_consolidados['percentual_desconto']
).round(2)

# %%
dados_consolidados
# Out:
#   matricula               nome_completo departamento  tipo_beneficio  \
# 0     10045  Maria Conceição dos Santos   Financeiro              VR
# 1     00123       Antônio Lopes Pereira           RH              VA
# 2     11501          Jaquelina da Silva           TI  Plano de Saúde
# 3     23256            José de Oliveira      Compras              VR
# 4     89856           Amando dos Santos   Licitações              VR
#
#    valor_mensal tipo_beneficio_desconto  percentual_desconto  valor_desconto
# 0        850.00                      VR                 0.05           42.50
# 1       1125.00                      VA                 0.03           33.75
# 2       2500.00          Plano de Saúde                 0.12          300.00
# 3        185.29                      VA                 1.12          207.52
# 4       1113.25          Plano de Saúde                 2.12         2360.09

# %%
dados_consolidados['valor_liquido'] = (
    dados_consolidados['valor_mensal'] - dados_consolidados['valor_desconto']
).round(2)

# %%
dados_consolidados
# Out:
#   matricula               nome_completo departamento  tipo_beneficio  \
# 0     10045  Maria Conceição dos Santos   Financeiro              VR
# 1     00123       Antônio Lopes Pereira           RH              VA
# 2     11501          Jaquelina da Silva           TI  Plano de Saúde
# 3     23256            José de Oliveira      Compras              VR
# 4     89856           Amando dos Santos   Licitações              VR
#
#    valor_mensal tipo_beneficio_desconto  percentual_desconto  valor_desconto  \
# 0        850.00                      VR                 0.05           42.50
# 1       1125.00                      VA                 0.03           33.75
# 2       2500.00          Plano de Saúde                 0.12          300.00
# 3        185.29                      VA                 1.12          207.52
# 4       1113.25          Plano de Saúde                 2.12         2360.09
#
#    valor_liquido
# 0         807.50
# 1        1091.25
# 2        2200.00
# 3         -22.23
# 4       -1246.84

# %%
dados_consolidados.to_excel('beneficios_consolidado.xlsx',
                            sheet_name='consolidado',
                            index=False)
