# %%
import pandas as pd

# %%
dados_brutos = pd.read_excel('beneficios_funcionarios.xlsx',
                             sheet_name='dados_brutos',
                             skiprows=3,
                             dtype={'matricula': str},
                             usecols='A:E')

# %%
dados_brutos
# Out:
#   matricula               nome_completo departamento  tipo_beneficio  \
# 0     10045  Maria Conceição dos Santos   Financeiro              VR
# 1     00123       Antônio Lopes Pereira           RH              VA
# 2     11501          Jaquelina da Silva           TI  Plano de Saúde
# 3     23256            José de Oliveira      Compras              VR
# 4     89856           Amando dos Santos   Licitações              VR
#
#    valor_mensal
# 0        850.00
# 1       1125.00
# 2       2500.00
# 3        185.29
# 4       1113.25

# %%
tabela_desconto = pd.read_excel('beneficios_funcionarios.xlsx',
                                sheet_name='tabela_desconto')

# %%
tabela_desconto
# Out:
#    tipo_beneficio  percentual_desconto
# 0              VR                 0.05
# 1              VA                 0.03
# 2  Plano de Saúde                 0.12

# %%
dados_consolidados = pd.merge(dados_brutos, tabela_desconto, how='left', on='tipo_beneficio')

# %%
dados_consolidados
# Out:
#   matricula               nome_completo departamento  tipo_beneficio  \
# 0     10045  Maria Conceição dos Santos   Financeiro              VR
# 1     00123       Antônio Lopes Pereira           RH              VA
# 2     11501          Jaquelina da Silva           TI  Plano de Saúde
# 3     23256            José de Oliveira      Compras              VR
# 4     89856           Amando dos Santos   Licitações              VR
#
#    valor_mensal  percentual_desconto
# 0        850.00                 0.05
# 1       1125.00                 0.03
# 2       2500.00                 0.12
# 3        185.29                 0.05
# 4       1113.25                 0.05

# %%
dados_consolidados['valor_desconto'] = (
    dados_consolidados['valor_mensal'] * dados_consolidados['percentual_desconto']
).round(2)

# %%
dados_consolidados
# Out:
#   matricula               nome_completo departamento  tipo_beneficio  \
# 0     10045  Maria Conceição dos Santos   Financeiro              VR
# 1     00123       Antônio Lopes Pereira           RH              VA
# 2     11501          Jaquelina da Silva           TI  Plano de Saúde
# 3     23256            José de Oliveira      Compras              VR
# 4     89856           Amando dos Santos   Licitações              VR
#
#    valor_mensal  percentual_desconto  valor_desconto
# 0        850.00                 0.05           42.50
# 1       1125.00                 0.03           33.75
# 2       2500.00                 0.12          300.00
# 3        185.29                 0.05            9.26
# 4       1113.25                 0.05           55.66

# %%
dados_consolidados['valor_liquido'] = (
    dados_consolidados['valor_mensal'] - dados_consolidados['valor_desconto']
).round(2)

# %%
dados_consolidados
# Out:
#   matricula               nome_completo departamento  tipo_beneficio  \
# 0     10045  Maria Conceição dos Santos   Financeiro              VR
# 1     00123       Antônio Lopes Pereira           RH              VA
# 2     11501          Jaquelina da Silva           TI  Plano de Saúde
# 3     23256            José de Oliveira      Compras              VR
# 4     89856           Amando dos Santos   Licitações              VR
#
#    valor_mensal  percentual_desconto  valor_desconto  valor_liquido
# 0        850.00                 0.05           42.50         807.50
# 1       1125.00                 0.03           33.75        1091.25
# 2       2500.00                 0.12          300.00        2200.00
# 3        185.29                 0.05            9.26         176.03
# 4       1113.25                 0.05           55.66        1057.59

# %%
dados_consolidados.to_excel('beneficios_consolidado.xlsx',
                            sheet_name='consolidado',
                            index=False)
