# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/ocfurtado/Pandas_io/refs/heads/main/superstore_data.csv'

# %%
dados_mercado = pd.read_csv(url)

# %%
dados_mercado.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
# ...

# %%
url_2 = 'https://raw.githubusercontent.com/ocfurtado/Pandas_io/refs/heads/main/superstore_data_ponto_virgula.csv'

# %%
dados_ponto_virgula = pd.read_csv(url_2, sep=';', encoding='ascii', nrows=5)

# %%
dados_ponto_virgula
# Out:
#       Id  Year_Birth   Education Marital_Status  Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced   84835        0         0
# 1      1        1961  Graduation         Single   57091        0         0
# 2  10476        1958  Graduation        Married   67267        0         1
# 3   1386        1967  Graduation       Together   32474        1         1
# 4   5371        1989  Graduation         Single   21474        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
#    MntGoldProds  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# ...

# %%
dados_ponto_virgula.to_csv('dados_ponto_virgula_somente_5_linhas.csv', index=False)

# %%
import chardet

# %%
caminho_arquivo = r'C:\Users\omar.furtado\Desktop\Pandas_io\superstore_data_ponto_virgula.csv'

# %%
with open(caminho_arquivo, 'rb') as file:
    dados_brutos = file.read()

    resultado = chardet.detect(dados_brutos)

    encoding_detectado = resultado['encoding']
    confianca = resultado['confidence']

print(f"Encoding: {encoding_detectado} (Confiança: {confianca})")
# Out:
# Encoding: ascii (Confiança: 1.0)

# %%
dados_ponto_virgula_5_linhas = pd.read_csv(r'C:\Users\omar.furtado\Desktop\Pandas_io\Aula_1\dados_ponto_virgula_somente_5_linhas.csv')

# %%
dados_ponto_virgula_5_linhas
# Out:
#       Id  Year_Birth   Education Marital_Status  Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced   84835        0         0
# 1      1        1961  Graduation         Single   57091        0         0
# 2  10476        1958  Graduation        Married   67267        0         1
# 3   1386        1967  Graduation       Together   32474        1         1
# 4   5371        1989  Graduation         Single   21474        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
#    MntGoldProds  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# ...

# %%
caminho_arquivo_dados_sus = r'C:\Users\omar.furtado\Desktop\Pandas_io\dados_sus.csv'

# %%
with open(caminho_arquivo_dados_sus, 'rb') as file:
    dados_brutos = file.read()

    resultado = chardet.detect(dados_brutos)

print(resultado)
# Out:
# {'encoding': 'ISO-8859-1', 'confidence': 0.73, 'language': ''}

# %%
dados_sus = pd.read_csv(caminho_arquivo_dados_sus, sep=';', skiprows=3, skipfooter=9, encoding='ISO-8859-1', engine='python')

# %%
dados_sus.head()
# Out:
#   Unidade da Federação     2008/Jan     2008/Fev     2008/Mar     2008/Abr  \
# 0             Rondônia   1388528,39   2931283,42   1541682,52   1525314,96
# 1                 Acre    902416,00   1497206,26   1794028,48   1730469,42
# 2             Amazonas   4735529,42   7118990,57   8196635,49   8259378,42
# 3              Roraima    657889,53    777939,31    718688,03    839994,39
# 4                 Pará  18864744,11  19553758,20  21937342,70  20842829,69
#
#       2008/Mai     2008/Jun     2008/Jul     2008/Ago     2008/Set  ...  \
# 0   1645953,84   1406150,68   3065279,01   3231494,61   3117178,63  ...
# 1   1819443,92   1828496,00   2511754,59   2089107,14   2275708,53  ...
# 2   7831399,90   8477273,62   9368858,72   9352532,70   9363099,35  ...
# 3    862347,96    832440,66    996693,09    894271,18    910424,17  ...
# 4  23249952,88  23240687,56  24002223,56  23341218,03  25172261,32  ...
#
#       2020/Jul     2020/Ago     2020/Set     2020/Out     2020/Nov  \
# ...

# %%
import pandas as pd
import chardet

# %%
pagamentos_fornecedores = pd.read_csv(r'C:\Users\omar.furtado\Desktop\Pandas_io\Aula_1\pagamentos_fornecedores.csv', sep=';', dtype=)

# %%
with open(r'C:\Users\omar.furtado\Desktop\Pandas_io\Aula_1\pagamentos_fornecedores.csv', 'rb') as file:
    dados_bruto = file.read()

    resultado = chardet.detect(dados_bruto)

print(resultado)
# Out:
# {'encoding': 'UTF-8-SIG', 'confidence': 1.0, 'language': ''}

# %%
pagamentos_fornecedores
# Out:
#   cod_fornecedor              nome_fornecedor data_pagamento valor_pago  \
# 0         F-0012        Açougue São José Ltda     15/01/2025     3450,9
# 1         F-0013       Padaria São Lucas Ltda     15/02/2025      156,8
# 2         F-0014      Supermercado Lotus Ltda     16/03/2025     1547,9
# 3         F-0015  Restaurante Claretiano Ltda     20/04/2025    3465,89
# 4         F-0016         Lanchonete Mila Ltda     28/05/2025       3000
#
#      status
# 0      pago
# 1  pendente
# 2      pago
# 3  pendente
# 4       NaN

# %%
pagamentos_fornecedores['valor_pago'] = pagamentos_fornecedores['valor_pago'].str.replace('.', '', regex=False).str.replace(',', '.').astype(float)

# %%
pagamentos_fornecedores
# Out:
#   cod_fornecedor              nome_fornecedor data_pagamento  valor_pago  \
# 0         F-0012        Açougue São José Ltda     15/01/2025     3450.90
# 1         F-0013       Padaria São Lucas Ltda     15/02/2025      156.80
# 2         F-0014      Supermercado Lotus Ltda     16/03/2025     1547.90
# 3         F-0015  Restaurante Claretiano Ltda     20/04/2025     3465.89
# 4         F-0016         Lanchonete Mila Ltda     28/05/2025     3000.00
#
#      status
# 0      pago
# 1  pendente
# 2      pago
# 3  pendente
# 4       NaN

# %%
pagamentos_fornecedores['status'] = pagamentos_fornecedores['status'].fillna('não informado')

# %%
pagamentos_fornecedores
# Out:
#   cod_fornecedor              nome_fornecedor data_pagamento  valor_pago  \
# 0         F-0012        Açougue São José Ltda     2025-01-15     3450.90
# 1         F-0013       Padaria São Lucas Ltda     2025-02-15      156.80
# 2         F-0014      Supermercado Lotus Ltda     2025-03-16     1547.90
# 3         F-0015  Restaurante Claretiano Ltda     2025-04-20     3465.89
# 4         F-0016         Lanchonete Mila Ltda     2025-05-28     3000.00
#
#           status
# 0           pago
# 1       pendente
# 2           pago
# 3       pendente
# 4  não informado

# %%
pagamentos_fornecedores['data_pagamento'] = pd.to_datetime(pagamentos_fornecedores['data_pagamento'], format='%d/%m/%Y')

# %%
pagamentos_fornecedores.dtypes
# Out:
# cod_fornecedor                str
# nome_fornecedor               str
# data_pagamento     datetime64[us]
# valor_pago                float64
# status                        str
# dtype: object

# %%
pagamentos_fornecedores.to_csv('pagamentos_limpo.csv', sep=',', index=False, encoding='UTF-8')

# %%
pagamentos_fornecedores['cod_fornecedor'] = pagamentos_fornecedores['cod_fornecedor'].astype(str)

# %%
pagamentos_fornecedores.dtypes
# Out:
# cod_fornecedor                str
# nome_fornecedor               str
# data_pagamento     datetime64[ns]
# valor_pago                float64
# status                        str
# dtype: object

# %%
pd.read_csv('pagamentos_fornecedores.csv')
# Out:
#                                                    cod_fornecedor;nome_fornecedor;data_pagamento;valor_pago;status
# F-0012;Açougue São José Ltda;15/01/2025;3450                                                   9;pago
# F-0013;Padaria São Lucas Ltda;15/02/2025;156                                               8;pendente
# F-0014;Supermercado Lotus Ltda;16/03/2025;1547                                                 9;pago
# F-0015;Restaurante Claretiano Ltda;20/04/2025;3465                                        89;pendente
# F-0016;Lanchonete Mila Ltda;28/05/2025;3000;                                                      NaN

# %%
pagamentos_fornecedores['valor_pago'] = pagamentos_fornecedores['valor_pago'].str.replace('.', '', regex=False).str.replace(',', '.')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 pagamentos_fornecedores['valor_pago'] = pagamentos_fornecedores['valor_pago'].str.replace('.', '', regex=False).str.replace(',', '.')
#
# File c:\Users\omar.furtado\Desktop\Pandas_io\.venv\Lib\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6199 if (
#    6200     name not in self._internal_names_set
#    6201     and name not in self._metadata
#    6202     and name not in self._accessors
#    6203     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204 ):
#    6205     return self[name]
# -> 6206 return object.__getattribute__(self, name)
#
# File c:\Users\omar.furtado\Desktop\Pandas_io\.venv\Lib\site-packages\pandas\core\accessor.py:230, in Accessor.__get__(self, obj, cls)
#     227 if obj is None:
# ...

# %%
print(pagamentos_fornecedores.columns.tolist())
# Out:
# ['cod_fornecedor', 'nome_fornecedor', 'data_pagamento', 'valor_pago', 'status']

# %%
print(pagamentos_fornecedores.columns)
# Out:
# Index(['cod_fornecedor', 'nome_fornecedor', 'data_pagamento', 'valor_pago',
#        'status'],
#       dtype='str')
