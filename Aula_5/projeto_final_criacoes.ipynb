# %%
import pandas as pd

# %%
caminho_do_arquivo = 'fornecedores.xlsx'
dados_financeiro_pagamentos = pd.read_excel(caminho_do_arquivo, decimal=',')

# %%
dados_financeiro_pagamentos
# Out:
#   cod_fornecedor                            razao_social          cidade  uf  \
# 0          F-201   Distribuidora Elétrica São Paulo Ltda       São Paulo  SP
# 1          F-305                  Eletropeças Mineira ME  Belo Horizonte  MG
# 2          F-118  Casa do Eletricista Conceição & Filhos        Curitiba  PR
# 3          F-410                Iluminação Nordeste S.A.          Recife  PE
# 4          F-500                  Materiais Rápidos Ltda          Manaus  AM
#
#    receita_anual
# 0        2500000
# 1         850000
# 2        1200000
# 3        3100000
# 4         420000

# %%
dados_financeiro_pagamentos.to_csv('fornecedores.csv', sep=';', index=False, encoding='latin-1', decimal=',')

# %%
tabela_1 = pd.DataFrame(data={
    'col1': [1, 2],
    'col2': [3, 4]
})

# %%
tabela_2 = pd.DataFrame(data={
    'cod_fornecedor': ['F-201', 'F-305', 'F-118', 'F-410'],
    'num_contrato': ['CTR-2024-001', 'CTR-2024-015', 'CTR-2024-022', 'CTR-2024-033'],
    'valor_contrato': ['250000.00', '180000.00', '320000.00', '95000.00'],
    'vigencia_fim': ['31/12/2025', '28/02/2026', '14/06/2026', '31/08/2026']
})

# %%
tabela_3 = pd.DataFrame(data={
    'col1': [1, 2],
    'col2': [3, 4]
})

# %%
tabela_1.to_html('tabela_1.html', index=False)
tabela_2.to_html('tabela_2.html', index=False)
tabela_3.to_html('tabela_3.html', index=False)
