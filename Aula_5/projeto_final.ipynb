# %%
import pandas as pd

# %%
dados_financeiro_pagamentos = pd.read_csv('financeiro_pagamentos.csv', sep=';', dtype={'cod_fornecedor': str}, decimal=',', encoding='latin-1')

# %%
dados_financeiro_pagamentos
# Out:
#   cod_fornecedor valor_pago data_pagamento forma_pagamento
# 0          F-201  45.000,00     2025-01-15          boleto
# 1          F-201  32.000,00     2025-02-10   transferencia
# 2          F-305  28.000,00     2025-01-20          boleto
# 3          F-118  55.000,00     2025-01-25          boleto
# 4          F-118  61.000,00     2025-02-08   transferencia
# 5          F-410  15.000,00     2025-02-05             pix

# %%
dados_financeiro_pagamentos.dtypes
# Out:
# cod_fornecedor     str
# valor_pago         str
# data_pagamento     str
# forma_pagamento    str
# dtype: object

# %%
dados_financeiro_pagamentos['data_pagamento'] = pd.to_datetime(dados_financeiro_pagamentos['data_pagamento'], format='%Y-%m-%d')

# %%
dados_financeiro_pagamentos.dtypes
# Out:
# cod_fornecedor                str
# valor_pago                    str
# data_pagamento     datetime64[us]
# forma_pagamento               str
# dtype: object

# %%
dados_financeiro_pagamentos['valor_pago'] = dados_financeiro_pagamentos['valor_pago'].str.replace('.', '', regex=False).str.replace(',', '.').astype('float64')

# %%
dados_financeiro_pagamentos['valor_pago']
# Out:
# 0    45000.0
# 1    32000.0
# 2    28000.0
# 3    55000.0
# 4    61000.0
# 5    15000.0
# Name: valor_pago, dtype: float64

# %%
dados_financeiro_pagamentos.dtypes
# Out:
# cod_fornecedor                str
# valor_pago                float64
# data_pagamento     datetime64[us]
# forma_pagamento               str
# dtype: object

# %%
dados_financeiro_pagamentos
# Out:
#   cod_fornecedor  valor_pago data_pagamento forma_pagamento
# 0          F-201     45000.0     2025-01-15          boleto
# 1          F-201     32000.0     2025-02-10   transferencia
# 2          F-305     28000.0     2025-01-20          boleto
# 3          F-118     55000.0     2025-01-25          boleto
# 4          F-118     61000.0     2025-02-08   transferencia
# 5          F-410     15000.0     2025-02-05             pix

# %%
#Prepar para ler o rh_responsaveis.xlsx
