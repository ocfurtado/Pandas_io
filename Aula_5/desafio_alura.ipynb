# %%
import sqlalchemy
import pandas as pd

# %%
from sqlalchemy import create_engine, inspect, text

# %%
caminho_do_banco = r'C:\Users\omar.furtado\AppData\Roaming\DBeaverData\workspace6\.metadata\sample-database-sqlite-1\Chinook.db'
string_conexao = f'sqlite:///{caminho_do_banco}'

# %%
engine = create_engine(string_conexao)

# %%
caminho_arquivo = r'C:\Users\omar.furtado\Desktop\Pandas_io\clientes_banco.csv'

# %%
dados = pd.read_csv(caminho_arquivo)

# %%
dados.to_sql('novos_clientes', engine, index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 dados.to_sql('novos_clientes', engine, index=False)
#
# File c:\Users\omar.furtado\Desktop\Pandas_io\.venv\Lib\site-packages\pandas\core\generic.py:3052, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2820 """
#    2821 Write records stored in a DataFrame to a SQL database.
#    2822
#    (...)   3048 3
#    3049 """  # noqa: E501
#    3050 from pandas.io import sql
# -> 3052 return sql.to_sql(
#    3053     self,
#    3054     name,
#    3055     con,
#    3056     schema=schema,
#    3057     if_exists=if_exists,
#    3058     index=index,
#    3059     index_label=index_label,
#    3060     chunksize=chunksize,
#    3061     dtype=dtype,
#    3062     method=method,
#    3063 )
#
# ...

# %%
inspector = inspect(engine)

# %%
print(inspector.get_table_names())
# Out:
# ['Album', 'Artist', 'Customer', 'Employee', 'Genre', 'Invoice', 'InvoiceLine', 'MediaType', 'Playlist', 'PlaylistTrack', 'Track', 'clientes', 'empregados', 'novos_clientes']

# %%
pd.read_sql_table('novos_clientes', engine)
# Out:
#         ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0          5008804     32   Ensino superior  União-estável                2
# 1          5008805     32   Ensino superior  União-estável                2
# 2          5008806     58      Ensino médio         Casado                2
# 3          5008808     52      Ensino médio       Solteiro                1
# 4          5008809     52      Ensino médio       Solteiro                1
# ...            ...    ...               ...            ...              ...
# 438458     6840104     62      Ensino médio     Divorciado                1
# 438459     6840222     43      Ensino médio       Solteiro                1
# 438460     6841878     22   Ensino superior       Solteiro                1
# 438461     6842765     59      Ensino médio         Casado                2
# 438462     6842885     51      Ensino médio         Casado                2
#
# ...

# %%
query = "UPDATE novos_clientes SET Rendimento_anual=300000 WHERE ID_Cliente=6840104"
with engine.connect() as conn:
    result = conn.execute(text(query))
    conn.commit()

# %%
pd.read_sql_table('novos_clientes', engine)
# Out:
#         ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0          5008804     32   Ensino superior  União-estável                2
# 1          5008805     32   Ensino superior  União-estável                2
# 2          5008806     58      Ensino médio         Casado                2
# 3          5008808     52      Ensino médio       Solteiro                1
# 4          5008809     52      Ensino médio       Solteiro                1
# ...            ...    ...               ...            ...              ...
# 438458     6840104     62      Ensino médio     Divorciado                1
# 438459     6840222     43      Ensino médio       Solteiro                1
# 438460     6841878     22   Ensino superior       Solteiro                1
# 438461     6842765     59      Ensino médio         Casado                2
# 438462     6842885     51      Ensino médio         Casado                2
#
# ...

# %%
query = "DELETE FROM novos_clientes WHERE ID_Cliente=5008809"
with engine.connect() as conn:
    result = conn.execute(text(query))
    conn.commit()

# %%
pd.read_sql_table('novos_clientes', engine)
# Out:
#         ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0          5008804     32   Ensino superior  União-estável                2
# 1          5008805     32   Ensino superior  União-estável                2
# 2          5008806     58      Ensino médio         Casado                2
# 3          5008808     52      Ensino médio       Solteiro                1
# 4          5008810     52      Ensino médio       Solteiro                1
# ...            ...    ...               ...            ...              ...
# 438457     6840104     62      Ensino médio     Divorciado                1
# 438458     6840222     43      Ensino médio       Solteiro                1
# 438459     6841878     22   Ensino superior       Solteiro                1
# 438460     6842765     59      Ensino médio         Casado                2
# 438461     6842885     51      Ensino médio         Casado                2
#
# ...

# %%
query = "INSERT INTO novos_clientes (ID_Cliente, Idade, Grau_escolaridade, Estado_civil, Tamanho_familia, Categoria_de_renda, Ocupacao, Anos_empregado, Rendimento_anual, Tem_carro, Moradia) VALUES (6850985, 33, 'Doutorado', 'Solteiro', 1, 'Empregado', 'TI', 2, 290000, 0, 'Casa/apartamento próprio')"
with engine.connect() as conn:
    result = conn.execute(text(query))
    conn.commit()

# %%
pd.read_sql_table('novos_clientes', engine)
# Out:
#         ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0          5008804     32   Ensino superior  União-estável                2
# 1          5008805     32   Ensino superior  União-estável                2
# 2          5008806     58      Ensino médio         Casado                2
# 3          5008808     52      Ensino médio       Solteiro                1
# 4          5008810     52      Ensino médio       Solteiro                1
# ...            ...    ...               ...            ...              ...
# 438458     6840222     43      Ensino médio       Solteiro                1
# 438459     6841878     22   Ensino superior       Solteiro                1
# 438460     6842765     59      Ensino médio         Casado                2
# 438461     6842885     51      Ensino médio         Casado                2
# 438462     6850985     33         Doutorado       Solteiro                1
#
# ...
